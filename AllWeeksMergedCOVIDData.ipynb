# %%
import pandas as pd
df1 = pd.read_excel(r'C:\Users\emloc\Desktop\EmilyEdits\Baseline.xlsx')
df2 = pd.read_excel(r'C:\Users\emloc\Desktop\EmilyEdits\Week_1.xlsx')
df3 = pd.read_excel(r'C:\Users\emloc\Desktop\EmilyEdits\Week_2.xlsx')
df4 = pd.read_excel(r'C:\Users\emloc\Desktop\EmilyEdits\Week_3.xlsx')
df5 = pd.read_excel(r'C:\Users\emloc\Desktop\EmilyEdits\Week_4.xlsx')
df6 = pd.read_excel(r'C:\Users\emloc\Desktop\EmilyEdits\Week_5.xlsx')
df7 = pd.read_excel(r'C:\Users\emloc\Desktop\EmilyEdits\Week_6.xlsx')
df8 = pd.read_excel(r'C:\Users\emloc\Desktop\EmilyEdits\Week_7.xlsx')
df9 = pd.read_excel(r'C:\Users\emloc\Desktop\EmilyEdits\Week_8.xlsx')
df10 = pd.read_excel(r'C:\Users\emloc\Desktop\EmilyEdits\Week_9.xlsx')
df11 = pd.read_excel(r'C:\Users\emloc\Desktop\EmilyEdits\Week_10.xlsx')
df12 = pd.read_excel(r'C:\Users\emloc\Desktop\EmilyEdits\Week_11.xlsx')
df13 = pd.read_excel(r'C:\Users\emloc\Desktop\EmilyEdits\Week_12.xlsx')
df14 = pd.read_excel(r'C:\Users\emloc\Desktop\EmilyEdits\Week_13.xlsx')
df15 = pd.read_excel(r'C:\Users\emloc\Desktop\EmilyEdits\Week_14.xlsx')
df16 = pd.read_excel(r'C:\Users\emloc\Desktop\EmilyEdits\Week_15.xlsx')
df17 = pd.read_excel(r'C:\Users\emloc\Desktop\EmilyEdits\Week_16.xlsx')
df18 = pd.read_excel(r'C:\Users\emloc\Desktop\EmilyEdits\Week_17.xlsx')
df19 = pd.read_excel(r'C:\Users\emloc\Desktop\EmilyEdits\Week_18.xlsx')
df20 = pd.read_excel(r'C:\Users\emloc\Desktop\EmilyEdits\Week_19.xlsx')
df21 = pd.read_excel(r'C:\Users\emloc\Desktop\EmilyEdits\Week_20.xlsx')
df22 = pd.read_excel(r'C:\Users\emloc\Desktop\EmilyEdits\Week_24.xlsx')
df23 = pd.read_excel(r'C:\Users\emloc\Desktop\EmilyEdits\Week_28.xlsx')
df24 = pd.read_excel(r'C:\Users\emloc\Desktop\EmilyEdits\Week_32.xlsx')
df25 = pd.read_excel(r'C:\Users\emloc\Desktop\EmilyEdits\Week_36.xlsx')
df26 = pd.read_excel(r'C:\Users\emloc\Desktop\EmilyEdits\Week_40.xlsx')
df27 = pd.read_excel(r'C:\Users\emloc\Desktop\EmilyEdits\Week_44.xlsx')
df28 = pd.read_excel(r'C:\Users\emloc\Desktop\EmilyEdits\Week_48.xlsx')
df29 = pd.read_excel(r'C:\Users\emloc\Desktop\EmilyEdits\Week_52.xlsx')
df30 = pd.read_excel(r'C:\Users\emloc\Desktop\EmilyEdits\Week_56.xlsx')

df_combine = df1.merge(df2, on = 'Email', how = 'left')
df_combine = df_combine.merge(df3, on = 'Email', how = 'left')
df_combine = df_combine.merge(df4, on = 'Email', how = 'left')
df_combine = df_combine.merge(df5, on = 'Email', how = 'left')
df_combine = df_combine.merge(df6, on = 'Email', how = 'left')
df_combine = df_combine.merge(df7, on = 'Email', how = 'left')
df_combine = df_combine.merge(df8, on = 'Email', how = 'left')
df_combine = df_combine.merge(df9, on = 'Email', how = 'left')
df_combine = df_combine.merge(df10, on = 'Email', how = 'left')
df_combine = df_combine.merge(df11, on = 'Email', how = 'left')
df_combine = df_combine.merge(df12, on = 'Email', how = 'left')
df_combine = df_combine.merge(df13, on = 'Email', how = 'left')
df_combine = df_combine.merge(df14, on = 'Email', how = 'left')
df_combine = df_combine.merge(df15, on = 'Email', how = 'left')
df_combine = df_combine.merge(df16, on = 'Email', how = 'left')
df_combine = df_combine.merge(df17, on = 'Email', how = 'left')
df_combine = df_combine.merge(df18, on = 'Email', how = 'left')
df_combine = df_combine.merge(df19, on = 'Email', how = 'left')
df_combine = df_combine.merge(df20, on = 'Email', how = 'left')
df_combine = df_combine.merge(df21, on = 'Email', how = 'left')
df_combine = df_combine.merge(df22, on = 'Email', how = 'left')
df_combine = df_combine.merge(df23, on = 'Email', how = 'left')
df_combine = df_combine.merge(df24, on = 'Email', how = 'left')
df_combine = df_combine.merge(df25, on = 'Email', how = 'left')
df_combine = df_combine.merge(df26, on = 'Email', how = 'left')
df_combine = df_combine.merge(df27, on = 'Email', how = 'left')
df_combine = df_combine.merge(df28, on = 'Email', how = 'left')
df_combine = df_combine.merge(df29, on = 'Email', how = 'left')
df_combine = df_combine.merge(df30, on = 'Email', how = 'left')

df_combine
# Out:
#                          Email  Baseline_VPA  Baseline_MPA  Baseline_MVPA  \
# 0         Danisalay9@gmail.com        1950.0         150.0         4050.0
# 1       Maggie.shea7@gmail.com         150.0          90.0          390.0
# 2        vaccarrl@clarkson.edu         630.0         240.0         1500.0
# 3      bergeron_c9@hotmail.com         120.0          60.0          300.0
# 4           jmfobare@gmail.com         180.0        1260.0         1620.0
# ...                        ...           ...           ...            ...
# 25526                      NaN           NaN           NaN            NaN
# 25527                      NaN           NaN           NaN            NaN
# 25528                      NaN           NaN           NaN            NaN
# 25529                      NaN           NaN           NaN            NaN
# 25530                      NaN           NaN           NaN            NaN
#
#        Baseline_LPA  Baseline_SB  \
# 0             540.0        420.0
# ...

# %%
df_combine.to_csv('combined.csv')
